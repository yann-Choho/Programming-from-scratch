# %% [markdown]
# # Random Forest classifieur from scratch
#
# Dans ce notebook, vous allez apprendre à construire votre propre algorithme de Random Forest classifieur à partir de la fonction d'arbre de décision classifieur de sklearn et des packages pandas et numpy.

# %% [markdown]
# ## Importation des packages

# %%
# Packages de gestion des données
import numpy as np
import pandas as pd

# Packages de visualisation
import matplotlib.pyplot as plt

# Packages de modélisation
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.datasets import make_moons, load_breast_cancer
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Importation des données

# %%
# Initialisation des données
data = make_moons(n_samples=100, shuffle=True, noise=None, random_state=123)

# Séparation des variables explicatives de la variables cible
X_train = np.array(data[0])
Y_train = np.array(data[1])

# Visualisation du jeu de données
plt.scatter(X_train[:, 0], X_train[:, 1], c=Y_train)
plt.show()

# %%
# Initialisation des données
data = make_moons(n_samples=100, shuffle=True, noise=0.08, random_state=123)

# Séparation des variables explicatives de la variables cible
X_test = np.array(data[0])
Y_test = np.array(data[1])

# Visualisation du jeu de données
plt.scatter(X_test[:, 0], X_test[:, 1], c=Y_test)
plt.show()

# %% [markdown]
# ## L'arbre de décision un algorithme peu performant

# %%
model_example = DecisionTreeClassifier(max_depth=4)
model_example.fit(X_train, Y_train)

Y_test_pred = model_example.predict(X_test)

# %%
# Visualisation du jeu de données
plt.scatter(X_test[:, 0], X_test[:, 1], c=Y_test_pred)

plt.show()

# %%
# Parameters
n_classes = 2
plot_colors = "ryb"
plot_step = 0.02

x_min, x_max = X_test[:, 0].min() - 1, X_test[:, 0].max() + 1
y_min, y_max = X_test[:, 1].min() - 1, X_test[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, plot_step), np.arange(y_min, y_max, plot_step))
plt.tight_layout(h_pad=0.5, w_pad=0.5, pad=2.5)

Z = model_example.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)
cs = plt.contourf(xx, yy, Z, cmap=plt.cm.RdYlBu)

plt.xlabel("X1")
plt.ylabel("x2")

# Plot the training points
for i, color in zip(range(n_classes), plot_colors):
    idx = np.where(Y_test == i)
    plt.scatter(X_test[idx, 0], X_test[idx, 1], c=color, cmap=plt.cm.RdYlBu, edgecolor='black', s=15)

plt.show()

# %%
plot_tree(model_example, filled=True)
plt.show()

# %% [markdown]
# ## l'arbre de décision un algorithme peu stable
#
# En ajoutant un léger de bruit dans les jeux d'entraînement on obtient des modèles d'arbres de décision très différent. Le modèle d'arbre de décision n'est pas stable

# %%
# Initialisation des données
data = make_moons(n_samples=100, shuffle=True, noise=0.1, random_state=100)

# Séparation des variables explicatives de la variables cible
X_train = np.array(data[0])
Y_train = np.array(data[1])

# Visualisation du jeu de données
plt.scatter(X_train[:, 0], X_train[:, 1], c=Y_train)
plt.show()

model_example = DecisionTreeClassifier(max_depth=10)
model_example.fit(X_train, Y_train)

Y_test_pred = model_example.predict(X_test)

# Parameters
n_classes = 2
plot_colors = "ryb"
plot_step = 0.02

x_min, x_max = X_test[:, 0].min() - 1, X_test[:, 0].max() + 1
y_min, y_max = X_test[:, 1].min() - 1, X_test[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, plot_step), np.arange(y_min, y_max, plot_step))
plt.tight_layout(h_pad=0.5, w_pad=0.5, pad=2.5)

Z = model_example.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)
cs = plt.contourf(xx, yy, Z, cmap=plt.cm.RdYlBu)

plt.xlabel("X1")
plt.ylabel("x2")

# Plot the training points
for i, color in zip(range(n_classes), plot_colors):
    idx = np.where(Y_test == i)
    plt.scatter(X_test[idx, 0], X_test[idx, 1], c=color, cmap=plt.cm.RdYlBu, edgecolor='black', s=15)

plt.show()

# %%
# Initialisation des données
data = make_moons(n_samples=100, shuffle=True, noise=0.1, random_state=200)

# Séparation des variables explicatives de la variables cible
X_train = np.array(data[0])
Y_train = np.array(data[1])

# Visualisation du jeu de données
plt.scatter(X_train[:, 0], X_train[:, 1], c=Y_train)
plt.show()

model_example = DecisionTreeClassifier(max_depth=10)
model_example.fit(X_train, Y_train)

Y_test_pred = model_example.predict(X_test)

# Parameters
n_classes = 2
plot_colors = "ryb"
plot_step = 0.02

x_min, x_max = X_test[:, 0].min() - 1, X_test[:, 0].max() + 1
y_min, y_max = X_test[:, 1].min() - 1, X_test[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, plot_step), np.arange(y_min, y_max, plot_step))
plt.tight_layout(h_pad=0.5, w_pad=0.5, pad=2.5)

Z = model_example.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)
cs = plt.contourf(xx, yy, Z, cmap=plt.cm.RdYlBu)

plt.xlabel("X1")
plt.ylabel("x2")

# Plot the training points
for i, color in zip(range(n_classes), plot_colors):
    idx = np.where(Y_test == i)
    plt.scatter(X_test[idx, 0], X_test[idx, 1], c=color, cmap=plt.cm.RdYlBu, edgecolor='black', s=15)

plt.show()

# %%
# Initialisation des données
data = make_moons(n_samples=100, shuffle=True, noise=0.1, random_state=400)

# Séparation des variables explicatives de la variables cible
X_train = np.array(data[0])
Y_train = np.array(data[1])

# Visualisation du jeu de données
plt.scatter(X_train[:, 0], X_train[:, 1], c=Y_train)
plt.show()

model_example = DecisionTreeClassifier(max_depth=10)
model_example.fit(X_train, Y_train)

Y_test_pred = model_example.predict(X_test)

# Parameters
n_classes = 2
plot_colors = "ryb"
plot_step = 0.02

x_min, x_max = X_test[:, 0].min() - 1, X_test[:, 0].max() + 1
y_min, y_max = X_test[:, 1].min() - 1, X_test[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, plot_step), np.arange(y_min, y_max, plot_step))
plt.tight_layout(h_pad=0.5, w_pad=0.5, pad=2.5)

Z = model_example.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)
cs = plt.contourf(xx, yy, Z, cmap=plt.cm.RdYlBu)

plt.xlabel("X1")
plt.ylabel("x2")

# Plot the training points
for i, color in zip(range(n_classes), plot_colors):
    idx = np.where(Y_test == i)
    plt.scatter(X_test[idx, 0], X_test[idx, 1], c=color, cmap=plt.cm.RdYlBu, edgecolor='black', s=15)

plt.show()

# %% [markdown]
# ## Random Forest
#
# En utilisant la théorie de l'ensemble learning, l'idée et de rendre les modèles d'abres plus performant et plus stable.
#
# On va commencer par créer la classe de notre random forest.

# %%
data = load_breast_cancer()

x = data['data']
y = data['target']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.33, random_state=42)

# %% [markdown]
# ### Création de la classe

# %%
class RandomForestClassifier():
  def __init__(self, n_estimators=100, max_depth=None, min_samples_split=2, 
               min_samples_leaf=1, min_weight_fraction_leaf=0, max_features="auto",
               max_leaf_nodes=None, min_impurity_decrease=0, random_state=None, 
               class_weight=None, max_sample=None, max_columns=4):
    self._n_estimators = n_estimators
    self._max_depth = max_depth
    self._min_samples_split = min_samples_split
    self._min_samples_leaf = min_samples_leaf
    self._min_weight_fraction_leaf = min_weight_fraction_leaf
    self._max_features = max_features
    self._max_leaf_nodes = max_leaf_nodes
    self._min_impurity_decrease = min_impurity_decrease
    self._random_state = random_state
    self._class_weight = class_weight
    self._max_sample = max_sample
    self._max_columns = max_columns
    self._model = dict()
    self._features = dict()

# %%
rf = RandomForestClassifier(n_estimators=20, max_depth=7, random_state=123)
print(rf._n_estimators)
print(rf._max_depth)
print(rf._random_state)
# Out:
# 20
# 7
# 123

# %% [markdown]
# ### Fonction d'entraînement

# %%
class RandomForestClassifier():
  def __init__(self, n_estimators=100, max_depth=None, min_samples_split=2, 
               min_samples_leaf=1, min_weight_fraction_leaf=0, max_features="auto",
               max_leaf_nodes=None, min_impurity_decrease=0, random_state=None, 
               class_weight=None, max_sample=None, max_columns=4):
    self._n_estimators = n_estimators
    self._max_depth = max_depth
    self._min_samples_split = min_samples_split
    self._min_samples_leaf = min_samples_leaf
    self._min_weight_fraction_leaf = min_weight_fraction_leaf
    self._max_features = max_features
    self._max_leaf_nodes = max_leaf_nodes
    self._min_impurity_decrease = min_impurity_decrease
    self._random_state = random_state
    self._class_weight = class_weight
    self._max_sample = max_sample
    self._max_columns = max_columns
    self._model = dict()
    self._features = dict()

  def fit(self, x, y):

    if not(self._max_sample) :
      self._max_sample = x.shape[0]

    for est in range(self._n_estimators) :
      rand_index = np.random.randint(low=0, high=x.shape[0], size=self._max_sample)

      rand_column = np.random.randint(low=0, high=x.shape[1], size=self._max_columns)

      x_samp = x[rand_index, :]
      x_samp = x_samp[:, rand_column]

      y_samp = y[rand_index]

      decision_tree_model = DecisionTreeClassifier(max_depth=self._max_depth, 
                                                   min_samples_split=self._min_samples_split,
                                                   min_samples_leaf=self._min_samples_leaf,
                                                   min_weight_fraction_leaf=self._min_weight_fraction_leaf,
                                                   max_features=self._max_features,
                                                   max_leaf_nodes=self._max_leaf_nodes,
                                                   min_impurity_decrease=self._min_impurity_decrease,
                                                   random_state=self._random_state,
                                                   class_weight=self._class_weight)
      self._model[est] = decision_tree_model.fit(x_samp, y_samp)
      self._features[est] = rand_column

# %%
rf = RandomForestClassifier(n_estimators=20, max_depth=7, random_state=123)
rf.fit(x_train, y_train)

# %%
rf._model
# Out:
# {0: DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                         max_depth=7, max_features='auto', max_leaf_nodes=None,
#                         min_impurity_decrease=0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0, presort='deprecated',
#                         random_state=123, splitter='best'),
#  1: DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                         max_depth=7, max_features='auto', max_leaf_nodes=None,
#                         min_impurity_decrease=0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0, presort='deprecated',
#                         random_state=123, splitter='best'),
#  2: DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
# ...

# %% [markdown]
# ### fonction de prédiction

# %%
class RandomForestClassifier():
  def __init__(self, n_estimators=100, max_depth=None, min_samples_split=2, 
               min_samples_leaf=1, min_weight_fraction_leaf=0, max_features="auto",
               max_leaf_nodes=None, min_impurity_decrease=0, random_state=None, 
               class_weight=None, max_sample=None, max_columns=4):
    self._n_estimators = n_estimators
    self._max_depth = max_depth
    self._min_samples_split = min_samples_split
    self._min_samples_leaf = min_samples_leaf
    self._min_weight_fraction_leaf = min_weight_fraction_leaf
    self._max_features = max_features
    self._max_leaf_nodes = max_leaf_nodes
    self._min_impurity_decrease = min_impurity_decrease
    self._random_state = random_state
    self._class_weight = class_weight
    self._max_sample = max_sample
    self._max_columns = max_columns
    self._model = dict()
    self._features = dict()

  def fit(self, x, y):

    if not(self._max_sample) :
      self._max_sample = x.shape[0]

    for est in range(self._n_estimators) :
      rand_index = np.random.randint(low=0, high=x.shape[0], size=self._max_sample)

      rand_column = np.random.randint(low=0, high=x.shape[1], size=self._max_columns)

      x_samp = x[rand_index, :]
      x_samp = x_samp[:, rand_column]

      y_samp = y[rand_index]

      decision_tree_model = DecisionTreeClassifier(max_depth=self._max_depth, 
                                                   min_samples_split=self._min_samples_split,
                                                   min_samples_leaf=self._min_samples_leaf,
                                                   min_weight_fraction_leaf=self._min_weight_fraction_leaf,
                                                   max_features=self._max_features,
                                                   max_leaf_nodes=self._max_leaf_nodes,
                                                   min_impurity_decrease=self._min_impurity_decrease,
                                                   random_state=self._random_state,
                                                   class_weight=self._class_weight)
      self._model[est] = decision_tree_model.fit(x_samp, y_samp)
      self._features[est] = rand_column

  def predict(self, x):

    pred = np.zeros(x.shape[0])

    for i in range(self._n_estimators):
      pred += self._model[i].predict(x[:, self._features[i]])

    pred = pred / self._n_estimators

    pred = np.where(pred >= 0.5, 1, 0)

    return pred

# %%
rf = RandomForestClassifier(n_estimators=20, max_depth=7, random_state=123)
rf.fit(x_train, y_train)

# %%
pred = rf.predict(x_test)
np.mean(pred == y_test)
# Out:
# 0.9627659574468085

# %% [markdown]
# ### Comparaison Random forest vs arbre de décision

# %%
class RandomForestClassifier():
  def __init__(self, n_estimators=100, max_depth=None, min_samples_split=2, 
               min_samples_leaf=1, min_weight_fraction_leaf=0, max_features="auto",
               max_leaf_nodes=None, min_impurity_decrease=0, random_state=None, 
               class_weight=None, max_sample=None, max_columns=4):
    self._n_estimators = n_estimators
    self._max_depth = max_depth
    self._min_samples_split = min_samples_split
    self._min_samples_leaf = min_samples_leaf
    self._min_weight_fraction_leaf = min_weight_fraction_leaf
    self._max_features = max_features
    self._max_leaf_nodes = max_leaf_nodes
    self._min_impurity_decrease = min_impurity_decrease
    self._random_state = random_state
    self._class_weight = class_weight
    self._max_sample = max_sample
    self._max_columns = max_columns
    self._model = dict()
    self._features = dict()

  def fit(self, x, y):

    if not(self._max_sample) :
      self._max_sample = x.shape[0]

    for est in range(self._n_estimators) :
      rand_index = np.random.randint(low=0, high=x.shape[0], size=self._max_sample)

      rand_column = np.random.randint(low=0, high=x.shape[1], size=self._max_columns)

      x_samp = x[rand_index, :]
      x_samp = x_samp[:, rand_column]

      y_samp = y[rand_index]

      decision_tree_model = DecisionTreeClassifier(max_depth=self._max_depth, 
                                                   min_samples_split=self._min_samples_split,
                                                   min_samples_leaf=self._min_samples_leaf,
                                                   min_weight_fraction_leaf=self._min_weight_fraction_leaf,
                                                   max_features=self._max_features,
                                                   max_leaf_nodes=self._max_leaf_nodes,
                                                   min_impurity_decrease=self._min_impurity_decrease,
                                                   random_state=self._random_state,
                                                   class_weight=self._class_weight)
      self._model[est] = decision_tree_model.fit(x_samp, y_samp)
      self._features[est] = rand_column

  def predict(self, x):

    pred = np.zeros(x.shape[0])

    for i in range(self._n_estimators):
      pred += self._model[i].predict(x[:, self._features[i]])

    pred = pred / self._n_estimators

    pred = np.where(pred >= 0.5, 1, 0)

    return pred

  def predict_trees(self, x):

    pred = np.zeros((self._n_estimators, x.shape[0]))

    for i in range(self._n_estimators):
      pred[i] = self._model[i].predict(x[:, self._features[i]])

    return pred

# %%
rf = RandomForestClassifier(n_estimators=20, max_depth=7, random_state=123)
rf.fit(x_train, y_train)

# %%
pred = rf.predict(x_test)
np.mean(pred == y_test)
# Out:
# 0.9468085106382979

# %%
pred_trees = rf.predict_trees(x_test)
pred_trees.shape
# Out:
# (20, 188)

# %%
list(map(lambda x: np.mean(x == y_test), pred_trees))
# Out:
# [0.8617021276595744,
#  0.9308510638297872,
#  0.776595744680851,
#  0.8776595744680851,
#  0.6648936170212766,
#  0.8563829787234043,
#  0.8829787234042553,
#  0.7287234042553191,
#  0.8882978723404256,
#  0.8882978723404256,
#  0.9042553191489362,
#  0.9042553191489362,
#  0.9095744680851063,
#  0.9042553191489362,
#  0.8936170212765957,
#  0.8031914893617021,
#  0.8191489361702128,
#  0.8936170212765957,
#  0.8723404255319149,
#  0.8936170212765957]
